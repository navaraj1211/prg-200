# %%
# Bank Account Manager
class BankAccount:
    def __init__(self, name, account_number, balance=0):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"NPR {amount} deposited into {self.name}'s account.")

    def withdraw(self, amount):
        if amount > self.balance:
            print(f"Insufficient funds for {self.name}.")
        else:
            self.balance -= amount
            print(f"NPR {amount} withdrawn from {self.name}'s account.")

    def get_balance(self):
        print(f"{self.name} ({self.account_number}) - Balance: NPR {self.balance}")


accounts_data = [
    ("Ramesh Thapa", "A001", 5000),
    ("Sunita Karki", "A002", 0),
    ("Bikash Rai", "A003", 12000)
]

accounts = []

for name, account_number, balance in accounts_data:
    account = BankAccount(name, account_number, balance)
    accounts.append(account)

accounts[1].deposit(3000)
accounts[2].withdraw(15000)
accounts[0].withdraw(2000)

print("\nFinal Balances:")
for account in accounts:
    account.get_balance()
# Out:
# NPR 3000 deposited into Sunita Karki's account.
# Insufficient funds for Bikash Rai.
# NPR 2000 withdrawn from Ramesh Thapa's account.
#
# Final Balances:
# Ramesh Thapa (A001) - Balance: NPR 3000
# Sunita Karki (A002) - Balance: NPR 3000
# Bikash Rai (A003) - Balance: NPR 12000

# %% [markdown]
# # Student Record Card

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def average(self):
        total = sum(self.marks)
        avg = total / len(self.marks)
        return avg

    def grade(self):
        avg = self.average()

        if avg >= 80:
            return "A"
        elif avg >= 65:
            return "B"
        elif avg >= 50:
            return "C"
        elif avg >= 40:
            return "D"
        else:
            return "F"

    def display(self):
        avg = self.average()
        grade = self.grade()

        if avg >= 40:
            status = "Pass"
        else:
            status = "Fail"

        print(f"Name: {self.name}")
        print(f"Average: {avg:.1f}")
        print(f"Grade: {grade}")
        print(f"Status: {status}")
        print()


students_data = [
    ("Aarav", [78, 85, 60, 90, 72]),
    ("Sita", [45, 50, 38, 60, 55]),
    ("Bishal", [30, 25, 40, 35, 28]),
    ("Priya", [90, 88, 95, 92, 87])
]

students = []

for name, marks in students_data:
    student = Student(name, marks)
    students.append(student)

for student in students:
    student.display()
# Out:
# Name: Aarav
# Average: 77.0
# Grade: B
# Status: Pass
#
# Name: Sita
# Average: 49.6
# Grade: D
# Status: Pass
#
# Name: Bishal
# Average: 31.6
# Grade: F
# Status: Fail
#
# Name: Priya
# Average: 90.4
# Grade: A
# Status: Pass

# %% [markdown]
# # food Delivery App

# %%
class DeliveryPartner:
    def __init__(self, name, partner_id, deliveries):
        self.name = name
        self.partner_id = partner_id
        self.deliveries = deliveries

    def total_earning(self):
        return 0

    def display(self):
        print(f"Name: {self.name}")
        print(f"Partner ID: {self.partner_id}")
        print(f"Deliveries: {self.deliveries}")
        print(f"Total Earning: NPR {self.total_earning()}")
        print()


class BikeRider(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, km_travelled):
        super().__init__(name, partner_id, deliveries)
        self.km_travelled = km_travelled

    def total_earning(self):
        return (self.deliveries * 80) + (self.km_travelled * 5)


class Walker(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, rainy_deliveries):
        super().__init__(name, partner_id, deliveries)
        self.rainy_deliveries = rainy_deliveries

    def total_earning(self):
        return (self.deliveries * 60) + (self.rainy_deliveries * 50)


class CarDriver(DeliveryPartner):
    def __init__(self, name, partner_id, deliveries, fuel_cost):
        super().__init__(name, partner_id, deliveries)
        self.fuel_cost = fuel_cost

    def total_earning(self):
        return (self.deliveries * 120) - self.fuel_cost


partners = [
    BikeRider("Santosh Rai", "B-01", 15, 42),
    Walker("Kabita Maharjan", "W-01", 18, 5),
    CarDriver("Roshan KC", "C-01", 20, 850)
]

highest = partners[0]

for partner in partners:
    partner.display()

    if partner.total_earning() > highest.total_earning():
        highest = partner

print("Partner with Highest Earning:")
print(f"{highest.name} earned NPR {highest.total_earning()}")
# Out:
# Name: Santosh Rai
# Partner ID: B-01
# Deliveries: 15
# Total Earning: NPR 1410
#
# Name: Kabita Maharjan
# Partner ID: W-01
# Deliveries: 18
# Total Earning: NPR 1330
#
# Name: Roshan KC
# Partner ID: C-01
# Deliveries: 20
# Total Earning: NPR 1550
#
# Partner with Highest Earning:
# Roshan KC earned NPR 1550

# %% [markdown]
# # Bus Ticket Booking (Sajha Yatayat)

# %%
class Bus:
    def __init__(self, route, total_seats):
        self.route = route
        self.total_seats = total_seats
        self.booked_seats = {}

    def book_seat(self, seat_number, passenger_name):
        if seat_number in self.booked_seats:
            print(f"Seat {seat_number} already booked.")
        else:
            self.booked_seats[seat_number] = passenger_name
            print(f"Seat {seat_number} booked for {passenger_name}.")

    def available_seats(self):
        remaining_seats = self.total_seats - len(self.booked_seats)
        return remaining_seats

    def passenger_list(self):
        print("\nPassenger List:")
        for seat_number, passenger_name in self.booked_seats.items():
            print(f"Seat {seat_number}: {passenger_name}")


bus = Bus("Kathmandu - Pokhara", 10)

bookings = [
    (3, "Ramila Shrestha"),
    (7, "Deepak Gurung"),
    (3, "Anita Rai"),
    (1, "Prakash Magar"),
    (7, "Suman Tamang")
]

print(f"Bus Route: {bus.route}")
print()

for seat_number, passenger_name in bookings:
    bus.book_seat(seat_number, passenger_name)

print(f"\nAvailable Seats: {bus.available_seats()}")

bus.passenger_list()
# Out:
# Bus Route: Kathmandu - Pokhara
#
# Seat 3 booked for Ramila Shrestha.
# Seat 7 booked for Deepak Gurung.
# Seat 3 already booked.
# Seat 1 booked for Prakash Magar.
# Seat 7 already booked.
#
# Available Seats: 7
#
# Passenger List:
# Seat 3: Ramila Shrestha
# Seat 7: Deepak Gurung
# Seat 1: Prakash Magar
